# %%
from Clustering import HierarchicalClustering
from Brands import Sonites

son = Sonites()
#df_comprehensive_feat = son.obtain_comprehensive_df_features()
#df_comprehensive_feat
#data = df_comprehensive_feat

df_comprehensive = son.get_comprehensive_df_semantic()
df_comprehensive
data = df_comprehensive
hc = HierarchicalClustering(data, n_clusters=3, linkage_method='ward', scale_data=True)

hc.plot_dendrogram()
# Out:
# ./Exports/TeamExport_A46051_Alpha_M_Period 3.xlsx loaded

# %%
centroids = hc.get_cluster_centroids()
centroids
# Out:
#            # Features Design Index Battery Life Display Size Proc. Power  \
# Centroid_0   0.478612    -1.031377     0.222567     0.654814    0.903021
# Centroid_1  -1.044122    -0.324173    -0.620224    -0.892752   -1.066355
# Centroid_2   0.870056     1.214109     0.566215     0.547451    0.557209
#
#                Price
# Centroid_0  0.426071
# Centroid_1 -1.074009
# Centroid_2  0.947954

# %%
hc.clusters_labels
# Out:
# array([1, 0, 1, 2, 2, 1, 1, 2, 0, 0, 0, 2, 2, 1, 1], dtype=int64)

# %%
hc.compute_wcd()
# Out:
# 1.4001110799598815

# %%
hc.get_pca_components()
# Out:
# array([[ 3.00712914, -0.20894792],
#        [-1.03110478,  0.53643252],
#        [ 1.41577061, -0.3228993 ],
#        [-2.71354697, -0.72508301],
#        [-0.80901453, -0.95159266],
#        [ 3.27092225,  0.11302468],
#        [ 1.70021551, -0.39049033],
#        [-2.39460201, -1.02244384],
#        [-0.67968281,  1.27853616],
#        [-0.51387543,  2.20467111],
#        [-1.4915839 ,  1.41226259],
#        [-0.81153671, -0.9574232 ],
#        [-2.41258601, -0.4486569 ],
#        [ 2.43986089, -0.33488662],
#        [ 1.02363477, -0.18250329]])

# %%
hc.plot_scatter(size=(15,10))
