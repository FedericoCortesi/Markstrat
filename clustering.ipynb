# %%
from Clustering import HierarchicalClustering
from Brands import Sonites

son = Sonites()
#df_comprehensive_feat = son.obtain_comprehensive_df_features()
#df_comprehensive_feat
#data = df_comprehensive_feat

df_comprehensive = son.get_comprehensive_df_mds()
df_comprehensive
data = df_comprehensive
hc = HierarchicalClustering(data, n_clusters=3, linkage_method='ward', scale_data=True)

hc.plot_dendrogram()
# Out:
# ./Exports/TeamExport_A46051_Alpha_M_Period 3.xlsx loaded

# %%
centroids = hc.get_cluster_centroids()
centroids
# Out:
#              Economy Performance Convenience
# Centroid_0  1.073253   -1.050907   -0.498238
# Centroid_1 -0.424048    0.877656   -0.838408
# Centroid_2 -0.948665    0.558964    1.268611

# %%
hc.clusters_labels
# Out:
# array([0, 1, 0, 2, 2, 0, 0, 2, 1, 1, 1, 2, 2, 0, 0], dtype=int64)

# %%
hc.compute_wcd()
# Out:
# 0.7304572540169566

# %%
hc.get_pca_components()
# Out:
# array([[ 2.47896366, -0.35209473],
#        [-0.13379276,  0.45914774],
#        [ 0.87047652, -0.44689072],
#        [-1.84870847, -0.58561638],
#        [-1.24852377, -0.59746072],
#        [ 2.64507115, -0.03787867],
#        [ 0.86578245, -0.14628914],
#        [-1.89354913, -0.92955681],
#        [-0.86421481,  1.49442841],
#        [-0.35767727,  1.91721299],
#        [-0.15915061,  1.04062243],
#        [-1.21264028, -0.61861475],
#        [-1.59717057, -0.35512334],
#        [ 1.91220612, -0.55213342],
#        [ 0.54292779, -0.2897529 ]])

# %%
hc.plot_scatter(size=(15,10))
