# %%
from Clustering import HierarchicalClustering
from Brands import Sonites

son = Sonites()
#df_comprehensive_feat = son.obtain_comprehensive_df_features()
#df_comprehensive_feat
#data = df_comprehensive_feat

df_comprehensive = son.obtain_comprehensive_df_semantic()
df_comprehensive
data = df_comprehensive


hc = HierarchicalClustering(data, n_clusters=3, linkage_method='ward', scale_data=True)



hc.plot_dendrogram()

# %% [markdown]
# ### Fix plot and pca reduction!

# %%
centroids = hc.get_cluster_centroids()
centroids
# Out:
#            # Features Design Index Battery Life Display Size Proc. Power  \
# Centroid_0   0.530337    -1.141124     0.376858     0.670114    0.717675
# Centroid_1  -0.951152     -0.25378    -0.664652    -0.790811   -0.881506
# Centroid_2   1.028976     1.236514     0.714334     0.683632    0.784003
#
#                Price
# Centroid_0   0.34654
# Centroid_1 -0.919039
# Centroid_2  1.118654

# %%
hc.data_scaled
# Out:
# array([[-0.88466732, -0.85717434, -0.42649813, -1.50307775, -1.54896284,
#         -1.26397418],
#        [ 0.73355595, -1.1020813 ,  1.29874254, -0.60468645, -0.50234027,
#          0.5552195 ],
#        [-0.88466732,  0.43657327, -1.03230783,  0.12525648, -0.49607307,
#         -0.92517698],
#        [ 1.06472723,  1.28842355,  1.65432649,  1.19209614,  0.68842793,
#          1.19598812],
#        [-1.17067888, -1.2351829 , -0.42649813, -1.50307775, -1.51762684,
#         -1.32289543],
#        [-1.17067888, -0.38333263,  0.02785914, -1.21609164, -0.6966235 ,
#          0.20905714],
#        [ 1.53137766,  1.35763638,  0.7653666 ,  0.31242133,  1.02685679,
#          1.32856094],
#        [-0.09437223, -1.2351829 , -1.39447668,  1.43541045,  1.30261363,
#          0.76144388],
#        [ 0.95182793, -1.08610911,  1.22630877,  1.17961849,  1.35275124,
#         -0.2770432 ],
#        [-0.01157942,  1.28842355, -0.26846082,  0.28122719,  0.5066791 ,
#          1.10024108],
#        [ 1.53137766,  1.01157221,  0.70610261,  0.94878183,  0.91404717,
#          0.84982576],
#        [-0.53091619, -0.02662032, -1.43398601, -0.80432896, -1.07892276,
#         -1.43337278],
#        [-1.0653062 ,  0.54305455, -0.69647854,  0.15645062,  0.04917342,
#         -0.77787384]])

# %%
pippo = hc._merge_scaled_data_centroids()
pippo
# Out:
#                 # Features Design Index Battery Life Display Size Proc. Power  \
# MOST             -0.884667    -0.857174    -0.426498    -1.503078   -1.548963
# MOVE              0.733556    -1.102081     1.298743    -0.604686    -0.50234
# ROBUDO           -0.884667     0.436573    -1.032308     0.125256   -0.496073
# ROCK              1.064727     1.288424     1.654326     1.192096    0.688428
# SOFT             -1.170679    -1.235183    -0.426498    -1.503078   -1.517627
# SOLO             -1.170679    -0.383333     0.027859    -1.216092   -0.696624
# TONE              1.531378     1.357636     0.765367     0.312421    1.026857
# TOPS             -0.094372    -1.235183    -1.394477      1.43541    1.302614
# Explorers_2       0.951828    -1.086109     1.226309     1.179618    1.352751
# High Earners_2   -0.011579     1.288424    -0.268461     0.281227    0.506679
# Professionals_2   1.531378     1.011572     0.706103     0.948782    0.914047
# Savers_2         -0.530916     -0.02662    -1.433986    -0.804329   -1.078923
# Shoppers_2       -1.065306     0.543055    -0.696479     0.156451    0.049173
# Centroid_0        0.530337    -1.141124     0.376858     0.670114    0.717675
# Centroid_1       -0.951152     -0.25378    -0.664652    -0.790811   -0.881506
# Centroid_2        1.028976     1.236514     0.714334     0.683632    0.784003
#
#                     Price
# MOST            -1.263974
# MOVE             0.555219
# ROBUDO          -0.925177
# ROCK             1.195988
# SOFT            -1.322895
# SOLO             0.209057
# TONE             1.328561
# TOPS             0.761444
# Explorers_2     -0.277043
# High Earners_2   1.100241
# Professionals_2  0.849826
# Savers_2        -1.433373
# Shoppers_2      -0.777874
# Centroid_0        0.34654
# Centroid_1      -0.919039
# Centroid_2       1.118654

# %%
hc.data.index
# Out:
# Index(['MOST', 'MOVE', 'ROBUDO', 'ROCK', 'SOFT', 'SOLO', 'TONE', 'TOPS',
#        'Explorers_2', 'High Earners_2', 'Professionals_2', 'Savers_2',
#        'Shoppers_2'],
#       dtype='object')

# %%
hc.plot_clusters()
