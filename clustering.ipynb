# %%
from Clustering import HierarchicalClustering
from Brands import Sonites

son = Sonites()
#df_comprehensive_feat = son.obtain_comprehensive_df_features()
#df_comprehensive_feat
#data = df_comprehensive_feat

df_comprehensive = son.obtain_comprehensive_df_semantic()
df_comprehensive
data = df_comprehensive


hc = HierarchicalClustering(data, n_clusters=3, linkage_method='ward', scale_data=True)

labels = hc.get_cluster_dict_labels()
print(labels)

hc.plot_dendrogram()
# Out:
# {'MOST': 1, 'MOVE': 0, 'ROBUDO': 1, 'ROCK': 2, 'SOFT': 1, 'SOLO': 1, 'TONE': 2, 'TOPS': 0, 'Explorers_2': 0, 'High Earners_2': 2, 'Professionals_2': 2, 'Savers_2': 1, 'Shoppers_2': 1}

# %% [markdown]
# ### Fix plot and pca reduction!

# %%
centroids = hc.get_cluster_centroids()[0]
centroids
# Out:
#    # Features  Design Index  Battery Life  Display Size  Proc. Power     Price
# 0    0.530337     -1.141124      0.376858      0.670114     0.717675  0.346540
# 1   -0.951152     -0.253780     -0.664652     -0.790811    -0.881506 -0.919039
# 2    1.028976      1.236514      0.714334      0.683632     0.784003  1.118654

# %%
hc.data_scaled
# Out:
#                  # Features  Design Index  Battery Life  Display Size  \
# MOST              -0.884667     -0.857174     -0.426498     -1.503078
# MOVE               0.733556     -1.102081      1.298743     -0.604686
# ROBUDO            -0.884667      0.436573     -1.032308      0.125256
# ROCK               1.064727      1.288424      1.654326      1.192096
# SOFT              -1.170679     -1.235183     -0.426498     -1.503078
# SOLO              -1.170679     -0.383333      0.027859     -1.216092
# TONE               1.531378      1.357636      0.765367      0.312421
# TOPS              -0.094372     -1.235183     -1.394477      1.435410
# Explorers_2        0.951828     -1.086109      1.226309      1.179618
# High Earners_2    -0.011579      1.288424     -0.268461      0.281227
# Professionals_2    1.531378      1.011572      0.706103      0.948782
# Savers_2          -0.530916     -0.026620     -1.433986     -0.804329
# Shoppers_2        -1.065306      0.543055     -0.696479      0.156451
#
#                  Proc. Power     Price
# MOST               -1.548963 -1.263974
# MOVE               -0.502340  0.555219
# ROBUDO             -0.496073 -0.925177
# ROCK                0.688428  1.195988
# SOFT               -1.517627 -1.322895
# SOLO               -0.696624  0.209057
# TONE                1.026857  1.328561
# TOPS                1.302614  0.761444
# Explorers_2         1.352751 -0.277043
# High Earners_2      0.506679  1.100241
# Professionals_2     0.914047  0.849826
# Savers_2           -1.078923 -1.433373
# Shoppers_2          0.049173 -0.777874

# %%
pippo = hc._merge_scaled_data_centroids()
pippo
# Out:
#                  # Features  Design Index  Battery Life  Display Size  \
# MOST              -0.884667     -0.857174     -0.426498     -1.503078
# MOVE               0.733556     -1.102081      1.298743     -0.604686
# ROBUDO            -0.884667      0.436573     -1.032308      0.125256
# ROCK               1.064727      1.288424      1.654326      1.192096
# SOFT              -1.170679     -1.235183     -0.426498     -1.503078
# SOLO              -1.170679     -0.383333      0.027859     -1.216092
# TONE               1.531378      1.357636      0.765367      0.312421
# TOPS              -0.094372     -1.235183     -1.394477      1.435410
# Explorers_2        0.951828     -1.086109      1.226309      1.179618
# High Earners_2    -0.011579      1.288424     -0.268461      0.281227
# Professionals_2    1.531378      1.011572      0.706103      0.948782
# Savers_2          -0.530916     -0.026620     -1.433986     -0.804329
# Shoppers_2        -1.065306      0.543055     -0.696479      0.156451
# 0                  0.530337     -1.141124      0.376858      0.670114
# 1                 -0.951152     -0.253780     -0.664652     -0.790811
# 2                  1.028976      1.236514      0.714334      0.683632
#
#                  Proc. Power     Price
# MOST               -1.548963 -1.263974
# MOVE               -0.502340  0.555219
# ROBUDO             -0.496073 -0.925177
# ROCK                0.688428  1.195988
# SOFT               -1.517627 -1.322895
# SOLO               -0.696624  0.209057
# TONE                1.026857  1.328561
# TOPS                1.302614  0.761444
# Explorers_2         1.352751 -0.277043
# High Earners_2      0.506679  1.100241
# Professionals_2     0.914047  0.849826
# Savers_2           -1.078923 -1.433373
# Shoppers_2          0.049173 -0.777874
# 0                   0.717675  0.346540
# 1                  -0.881506 -0.919039
# 2                   0.784003  1.118654

# %%
for i, j in enumerate(list(pippo.index)):
    print(i)
    print(j)
    print()
# Out:
# 0
# MOST
#
# 1
# MOVE
#
# 2
# ROBUDO
#
# 3
# ROCK
#
# 4
# SOFT
#
# 5
# SOLO
#
# 6
# TONE
#
# 7
# TOPS
#
# 8
# Explorers_2
#
# 9
# High Earners_2
#
# 10
# Professionals_2
#
# 11
# Savers_2
#
# 12
# Shoppers_2
#
# 13
# 0
#
# 14
# 1
#
# 15
# 2

# %%
hc.plot_clusters()
