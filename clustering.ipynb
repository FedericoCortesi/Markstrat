# %%
from Clustering import HierarchicalClustering
from Brands import Brands

son = Brands(sector="Vodites")
#df_comprehensive_feat = son.obtain_comprehensive_df_features()
#df_comprehensive_feat
#data = df_comprehensive_feat

df_comprehensive = son.get_comprehensive_df_semantic()
df_comprehensive
data = df_comprehensive
hc = HierarchicalClustering(data, n_clusters=3, linkage_method='ward', scale_data=True)

hc.plot_dendrogram()
# Out:
# Vodites
# ./Exports/TeamExport_A46051_Alpha_M_Period 9.xlsx loaded

# %%
centroids = hc.get_cluster_centroids()
centroids
# Out:
#            Resolution Energy Efficiency Carbon Footprint Connectivity  \
# Centroid_0   1.136554         -0.239788         0.514259      1.28613
# Centroid_1  -0.220997          0.795755        -0.629968    -0.676255
# Centroid_2  -1.610119          -1.90769         0.861385    -0.543494
#
#            No. of Apps     Price
# Centroid_0    0.623141  0.527505
# Centroid_1   -0.424458 -0.915555
# Centroid_2    0.027093  1.691655

# %%
hc.clusters_labels
# Out:
# array([1, 2, 1, 0, 1, 0], dtype=int64)

# %%
hc.compute_wcd()
# Out:
# 1.162571482335081

# %%
hc.get_pca_components()
# Out:
# array([[ 0.69152949, -0.22037301],
#        [-1.94148939,  2.49624078],
#        [ 1.62430379, -0.0563569 ],
#        [-1.54869499, -0.97377261],
#        [ 2.43495916,  0.54440782],
#        [-1.26060807, -1.79014608]])

# %%
hc.plot_scatter(size=(20,10))

# %%
df = son.get_comprehensive_df_features()
df_corr = df.corr()
df_corr
# Out:
#                    Resolution  Energy Efficiency  Carbon Footprint  \
# Resolution           1.000000           0.294037          0.059492
# Energy Efficiency    0.294037           1.000000         -0.484877
# Carbon Footprint     0.059492          -0.484877          1.000000
# Connectivity         0.818056          -0.277541          0.401750
# No. of Apps          0.113762          -0.015810          0.541640
# Price               -0.122648          -0.944404          0.665324
# Autonomy             0.956604           0.503558         -0.005531
# Sophistication       0.912029           0.501357         -0.323936
# Economy              0.123999           0.946802         -0.665551
#
#                    Connectivity  No. of Apps     Price  Autonomy  \
# Resolution             0.818056     0.113762 -0.122648  0.956604
# Energy Efficiency     -0.277541    -0.015810 -0.944404  0.503558
# Carbon Footprint       0.401750     0.541640  0.665324 -0.005531
# Connectivity           1.000000     0.112966  0.406536  0.690252
# No. of Apps            0.112966     1.000000  0.305383  0.086987
# Price                  0.406536     0.305383  1.000000 -0.346730
# Autonomy               0.690252     0.086987 -0.346730  1.000000
# Sophistication         0.579883     0.032130 -0.376142  0.898886
# Economy               -0.407259    -0.296224 -0.999938  0.347862
#
#                    Sophistication   Economy
# Resolution               0.912029  0.123999
# Energy Efficiency        0.501357  0.946802
# Carbon Footprint        -0.323936 -0.665551
# Connectivity             0.579883 -0.407259
# No. of Apps              0.032130 -0.296224
# Price                   -0.376142 -0.999938
# Autonomy                 0.898886  0.347862
# Sophistication           1.000000  0.379210
# Economy                  0.379210  1.000000
