# %%
from Clustering import HierarchicalClustering
from Brands import Sonites

son = Sonites()
#df_comprehensive_feat = son.obtain_comprehensive_df_features()
#df_comprehensive_feat
#data = df_comprehensive_feat

df_comprehensive = son.get_comprehensive_df_semantic()
df_comprehensive
data = df_comprehensive
hc = HierarchicalClustering(data, n_clusters=3, linkage_method='ward', scale_data=True)

hc.plot_dendrogram()
# Out:
# ./Exports/TeamExport_A46051_Alpha_M_Period 4.xlsx loaded

# %%
centroids = hc.get_cluster_centroids()
centroids
# Out:
#            # Features Design Index Battery Life Display Size Proc. Power  \
# Centroid_0    0.59828    -1.206856     0.571168     1.079132    0.998655
# Centroid_1  -0.916114     -0.31293     -0.67126    -0.840599   -0.945735
# Centroid_2   0.923591     1.162216     0.597063     0.529359    0.724837
#
#                Price
# Centroid_0  0.372979
# Centroid_1  -0.95188
# Centroid_2  1.108845

# %%
hc.clusters_labels
# Out:
# array([1, 0, 1, 1, 2, 2, 1, 1, 2, 0, 0, 2, 2, 1, 1], dtype=int64)

# %%
hc.compute_wcd()
# Out:
# 1.273438957998936

# %%
hc.get_pca_components()
# Out:
# array([[ 2.61141742, -0.13227634],
#        [-1.73413481,  1.36094876],
#        [ 2.23951972, -0.75510196],
#        [ 1.26719966, -0.37506747],
#        [-2.90456182, -0.51123368],
#        [-0.93330537, -1.2106121 ],
#        [ 3.10809712,  0.83511965],
#        [ 1.53237987,  0.085007  ],
#        [-2.46682306, -0.92403358],
#        [-0.49927553,  1.69730401],
#        [-1.69261029,  1.8354073 ],
#        [-0.89387202, -1.21022884],
#        [-2.64024818, -0.31166677],
#        [ 2.22713183, -0.27626222],
#        [ 0.77908545, -0.10730377]])

# %%
hc.plot_scatter(size=(15,10))

# %%
df = son.get_comprehensive_df_features()
df_corr = df.corr()
df_corr
# Out:
#               # Features  Design Index  Battery Life  Display Size  \
# # Features      1.000000      0.411406      0.738334      0.747357
# Design Index    0.411406      1.000000      0.170491      0.215624
# Battery Life    0.738334      0.170491      1.000000      0.449218
# Display Size    0.747357      0.215624      0.449218      1.000000
# Proc. Power     0.794202      0.278686      0.587988      0.946272
# Price           0.738490      0.470444      0.626447      0.646529
# Economy        -0.738537     -0.470804     -0.626415     -0.646545
# Performance     0.789090      0.263095      0.554886      0.971974
# Convenience     0.618976      0.958718      0.429785      0.346206
#
#               Proc. Power     Price   Economy  Performance  Convenience
# # Features       0.794202  0.738490 -0.738537     0.789090     0.618976
# Design Index     0.278686  0.470444 -0.470804     0.263095     0.958718
# Battery Life     0.587988  0.626447 -0.626415     0.554886     0.429785
# Display Size     0.946272  0.646529 -0.646545     0.971974     0.346206
# Proc. Power      1.000000  0.822587 -0.822472     0.995771     0.442820
# Price            0.822587  1.000000 -0.999998     0.781386     0.618157
# Economy         -0.822472 -0.999998  1.000000    -0.781308    -0.618444
# Performance      0.995771  0.781386 -0.781308     1.000000     0.419491
# Convenience      0.442820  0.618157 -0.618444     0.419491     1.000000
